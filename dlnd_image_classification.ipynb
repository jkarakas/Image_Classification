# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile('cifar-10-python.tar.gz'):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            'cifar-10-python.tar.gz',
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open('cifar-10-python.tar.gz') as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself "What are all possible labels?", "What is the range of values for the image data?", "Are the labels in order or random?".  Answers to questions like these will help you preprocess the data and end up with better predictions.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 3
sample_id = 5
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %%
def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    # TODO: Implement Function
    a, b = 0.0, 1.0
    _min, _max = 0, 255
 
    return a + ( ( (x - _min)*(b - a) )/(_max - _min ) )


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)

# %% [markdown]
# ### One-hot encode
# Just like the previous code cell, you'll be implementing a function for preprocessing.  This time, you'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.
#
# Hint: Don't reinvent the wheel.

# %%
from sklearn.preprocessing import LabelBinarizer

def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    # TODO: Implement Function
    encoder = LabelBinarizer()
    encoder.fit(np.array([10*[0],10*[0]]))
    return encoder.transform(x)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# >**Note:** If you're finding it hard to dedicate enough time for this course each week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages to build each layer, except the layers you build in the "Convolutional and Max Pooling Layer" section.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# >However, if you would like to get the most out of this course, try to solve all the problems _without_ using anything from the TF Layers packages. You **can** still use classes from other packages that happen to have the same name as ones you find in TF Layers! For example, instead of using the TF Layers version of the `conv2d` class, [tf.layers.conv2d](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d), you would want to use the TF Neural Network version of `conv2d`, [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d).
#
# Let's begin!
#
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
import tensorflow as tf

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a bach of image input,  , 
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, shape=[None, image_shape[0], image_shape[1], image_shape[2]], name='x')
     


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    # TODO: Implement Function
    return  tf.placeholder(tf.float32, shape=[None, n_classes], name = 'y')
    


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    # TODO: Implement Function
    return  tf.placeholder(tf.float32, name = 'keep_prob')

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# **Note:** You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for **this** layer, but you can still use TensorFlow's [Neural Network](https://www.tensorflow.org/api_docs/python/tf/nn) package. You may still use the shortcut option for all the **other** layers.

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    # TODO: Implement Function
    weight = tf.Variable(tf.random_normal([conv_ksize[0], conv_ksize[1], x_tensor.get_shape().as_list()[3], conv_num_outputs], mean=0.0, stddev=0.1))
    bias = tf.Variable(tf.zeros([conv_num_outputs]))
    
    x = tf.nn.conv2d(x_tensor, weight, strides=[1, conv_strides[0], conv_strides[1], 1], padding='SAME')
    x = tf.nn.bias_add(x, bias) 
    x = tf.nn.relu(x)

    return tf.nn.max_pool(x, ksize=[1, pool_ksize[0], pool_ksize[1], 1], strides=[1, pool_strides[0], pool_strides[1], 1], padding='SAME')



"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# Tests Passed

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    # TODO: Implement Function
    s = x_tensor.get_shape().as_list()
    return tf.reshape(x_tensor, [-1, s[1]*s[2]*s[3]])

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# Tests Passed

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    wfc = tf.Variable(tf.random_normal([x_tensor.get_shape().as_list()[1], num_outputs], mean=0.0, stddev=0.1))
    dfc = tf.Variable(tf.zeros([num_outputs]))
    
    fc = tf.add(tf.matmul(x_tensor, wfc), dfc)
    
    return tf.nn.relu(fc)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# Tests Passed

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.
#
# **Note:** Activation, softmax, or cross entropy should **not** be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    wout = tf.Variable(tf.random_normal([x_tensor.get_shape().as_list()[1], num_outputs], mean=0.0, stddev=0.1))
    dout = tf.Variable(tf.zeros([num_outputs]))
    
    
    return tf.add(tf.matmul(x_tensor, wout), dout)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tests Passed

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    # TODO: Apply 1, 2, or 3 Convolution and Max Pool layers
    #    Play around with different number of outputs, kernel size and stride
    # Function Definition from Above:
    #    conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    
    conv = conv2d_maxpool(x, conv_num_outputs=32, conv_ksize=(5,5), conv_strides=(2,2), pool_ksize=(2,2), pool_strides=(2,2))
    
    conv = conv2d_maxpool(conv, conv_num_outputs=64, conv_ksize=(3,3), conv_strides=(2,2), pool_ksize=(2,2), pool_strides=(2,2))
       
    
    # TODO: Apply a Flatten Layer
    # Function Definition from Above:
    #   flatten(x_tensor)
    
    x_tensor = flatten(conv)

    # TODO: Apply 1, 2, or 3 Fully Connected Layers
    #    Play around with different number of outputs
    # Function Definition from Above:
    #   fully_conn(x_tensor, num_outputs)
    
    fc = fully_conn(x_tensor, 1024)
    fc = tf.nn.dropout(fc, keep_prob)
    
    fc = fully_conn(fc, 512//2)
    
    # TODO: Apply an Output Layer
    #    Set this to the number of classes
    # Function Definition from Above:
    #   output(x_tensor, num_outputs)
    global y
    out = output(fc, num_outputs = y.get_shape().as_list()[1])
    
    # TODO: return output
    return out


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# Neural Network Built!

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    # TODO: Implement Function
    session.run(optimizer, feed_dict={
            x: feature_batch,
            y: label_batch,
            keep_prob: keep_probability
        })


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    # TODO: Implement Function
    loss = session.run(cost, feed_dict={
            x: feature_batch,
            y: label_batch,
            keep_prob: 1.})
    valid_acc = session.run(accuracy, feed_dict={
            x: valid_features,
            y: valid_labels,
            keep_prob: 1.})
                
    print('Loss: {:10.4f} Validation Accuracy: {:.6f}'.format(loss, valid_acc))

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
# TODO: Tune Parameters
epochs = 75
batch_size = 92
keep_probability = 0.40

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:  Loss:     1.9834 Validation Accuracy: 0.371000
# Epoch  2, CIFAR-10 Batch 1:  Loss:     1.9413 Validation Accuracy: 0.385600
# Epoch  3, CIFAR-10 Batch 1:  Loss:     1.8487 Validation Accuracy: 0.418200
# Epoch  4, CIFAR-10 Batch 1:  Loss:     1.6572 Validation Accuracy: 0.431400
# Epoch  5, CIFAR-10 Batch 1:  Loss:     1.5862 Validation Accuracy: 0.475400
# Epoch  6, CIFAR-10 Batch 1:  Loss:     1.4717 Validation Accuracy: 0.489800
# Epoch  7, CIFAR-10 Batch 1:  Loss:     1.4549 Validation Accuracy: 0.496600
# Epoch  8, CIFAR-10 Batch 1:  Loss:     1.3454 Validation Accuracy: 0.501200
# Epoch  9, CIFAR-10 Batch 1:  Loss:     1.2318 Validation Accuracy: 0.503400
# Epoch 10, CIFAR-10 Batch 1:  Loss:     1.1563 Validation Accuracy: 0.519400
# Epoch 11, CIFAR-10 Batch 1:  Loss:     1.1071 Validation Accuracy: 0.517000
# Epoch 12, CIFAR-10 Batch 1:  Loss:     0.9910 Validation Accuracy: 0.528000
# Epoch 13, CIFAR-10 Batch 1:  Loss:     0.9127 Validation Accuracy: 0.525800
# Epoch 14, CIFAR-10 Batch 1:  Loss:     0.9700 Validation Accuracy: 0.516400
# Epoch 15, CIFAR-10 Batch 1:  Loss:     0.8881 Validation Accuracy: 0.521000
# Epoch 16, CIFAR-10 Batch 1:  Loss:     0.8202 Validation Accuracy: 0.519800
# Epoch 17, CIFAR-10 Batch 1:  Loss:     0.7339 Validation Accuracy: 0.530800
# Epoch 18, CIFAR-10 Batch 1:  Loss:     0.6593 Validation Accuracy: 0.527800
# Epoch 19, CIFAR-10 Batch 1:  Loss:     0.7283 Validation Accuracy: 0.506400
# Epoch 20, CIFAR-10 Batch 1:  Loss:     0.6351 Validation Accuracy: 0.518600
# Epoch 21, CIFAR-10 Batch 1:  Loss:     0.5985 Validation Accuracy: 0.509000
# Epoch 22, CIFAR-10 Batch 1:  Loss:     0.5293 Validation Accuracy: 0.507400
# Epoch 23, CIFAR-10 Batch 1:  Loss:     0.4198 Validation Accuracy: 0.530400
# Epoch 24, CIFAR-10 Batch 1:  Loss:     0.3844 Validation Accuracy: 0.530800
# Epoch 25, CIFAR-10 Batch 1:  Loss:     0.3590 Validation Accuracy: 0.527600
# Epoch 26, CIFAR-10 Batch 1:  Loss:     0.3379 Validation Accuracy: 0.531600
# Epoch 27, CIFAR-10 Batch 1:  Loss:     0.3194 Validation Accuracy: 0.536800
# Epoch 28, CIFAR-10 Batch 1:  Loss:     0.2974 Validation Accuracy: 0.533200
# Epoch 29, CIFAR-10 Batch 1:  Loss:     0.3225 Validation Accuracy: 0.526000
# Epoch 30, CIFAR-10 Batch 1:  Loss:     0.2450 Validation Accuracy: 0.528400
# Epoch 31, CIFAR-10 Batch 1:  Loss:     0.2110 Validation Accuracy: 0.530000
# Epoch 32, CIFAR-10 Batch 1:  Loss:     0.1824 Validation Accuracy: 0.527800
# Epoch 33, CIFAR-10 Batch 1:  Loss:     0.2274 Validation Accuracy: 0.521400
# Epoch 34, CIFAR-10 Batch 1:  Loss:     0.1779 Validation Accuracy: 0.528800
# Epoch 35, CIFAR-10 Batch 1:  Loss:     0.1876 Validation Accuracy: 0.531000
# Epoch 36, CIFAR-10 Batch 1:  Loss:     0.1724 Validation Accuracy: 0.510200
# Epoch 37, CIFAR-10 Batch 1:  Loss:     0.1202 Validation Accuracy: 0.517200
# Epoch 38, CIFAR-10 Batch 1:  Loss:     0.1990 Validation Accuracy: 0.525800
# Epoch 39, CIFAR-10 Batch 1:  Loss:     0.1323 Validation Accuracy: 0.527400
# Epoch 40, CIFAR-10 Batch 1:  Loss:     0.1112 Validation Accuracy: 0.534200
# Epoch 41, CIFAR-10 Batch 1:  Loss:     0.1278 Validation Accuracy: 0.520200
# Epoch 42, CIFAR-10 Batch 1:  Loss:     0.1060 Validation Accuracy: 0.536400
# Epoch 43, CIFAR-10 Batch 1:  Loss:     0.1112 Validation Accuracy: 0.531600
# Epoch 44, CIFAR-10 Batch 1:  Loss:     0.1244 Validation Accuracy: 0.531400
# Epoch 45, CIFAR-10 Batch 1:  Loss:     0.1019 Validation Accuracy: 0.528000
# Epoch 46, CIFAR-10 Batch 1:  Loss:     0.0986 Validation Accuracy: 0.528400
# Epoch 47, CIFAR-10 Batch 1:  Loss:     0.1556 Validation Accuracy: 0.520800
# Epoch 48, CIFAR-10 Batch 1:  Loss:     0.1807 Validation Accuracy: 0.524000
# Epoch 49, CIFAR-10 Batch 1:  Loss:     0.0574 Validation Accuracy: 0.529200
# Epoch 50, CIFAR-10 Batch 1:  Loss:     0.0947 Validation Accuracy: 0.519600

# %% [markdown]
# ### Fully Train the Model
# Now that you got a good accuracy with a single CIFAR-10 batch, try it with all five batches.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:  Loss:     1.9606 Validation Accuracy: 0.342600
# Epoch  1, CIFAR-10 Batch 2:  Loss:     1.7019 Validation Accuracy: 0.387600
# Epoch  1, CIFAR-10 Batch 3:  Loss:     1.4534 Validation Accuracy: 0.431000
# Epoch  1, CIFAR-10 Batch 4:  Loss:     1.4385 Validation Accuracy: 0.453000
# Epoch  1, CIFAR-10 Batch 5:  Loss:     1.5004 Validation Accuracy: 0.464800
# Epoch  2, CIFAR-10 Batch 1:  Loss:     1.6550 Validation Accuracy: 0.482400
# Epoch  2, CIFAR-10 Batch 2:  Loss:     1.4487 Validation Accuracy: 0.484200
# Epoch  2, CIFAR-10 Batch 3:  Loss:     1.2476 Validation Accuracy: 0.499800
# Epoch  2, CIFAR-10 Batch 4:  Loss:     1.2893 Validation Accuracy: 0.517800
# Epoch  2, CIFAR-10 Batch 5:  Loss:     1.3847 Validation Accuracy: 0.531200
# Epoch  3, CIFAR-10 Batch 1:  Loss:     1.4388 Validation Accuracy: 0.536400
# Epoch  3, CIFAR-10 Batch 2:  Loss:     1.3181 Validation Accuracy: 0.531400
# Epoch  3, CIFAR-10 Batch 3:  Loss:     1.1181 Validation Accuracy: 0.534200
# Epoch  3, CIFAR-10 Batch 4:  Loss:     1.2273 Validation Accuracy: 0.554800
# Epoch  3, CIFAR-10 Batch 5:  Loss:     1.1933 Validation Accuracy: 0.565800
# Epoch  4, CIFAR-10 Batch 1:  Loss:     1.3722 Validation Accuracy: 0.563000
# Epoch  4, CIFAR-10 Batch 2:  Loss:     1.2210 Validation Accuracy: 0.567400
# Epoch  4, CIFAR-10 Batch 3:  Loss:     0.9423 Validation Accuracy: 0.573200
# Epoch  4, CIFAR-10 Batch 4:  Loss:     1.1333 Validation Accuracy: 0.575600
# Epoch  4, CIFAR-10 Batch 5:  Loss:     1.1222 Validation Accuracy: 0.589600
# Epoch  5, CIFAR-10 Batch 1:  Loss:     1.2889 Validation Accuracy: 0.569000
# Epoch  5, CIFAR-10 Batch 2:  Loss:     1.1052 Validation Accuracy: 0.590800
# Epoch  5, CIFAR-10 Batch 3:  Loss:     0.8933 Validation Accuracy: 0.585200
# Epoch  5, CIFAR-10 Batch 4:  Loss:     1.0802 Validation Accuracy: 0.593400
# Epoch  5, CIFAR-10 Batch 5:  Loss:     1.0218 Validation Accuracy: 0.609600
# Epoch  6, CIFAR-10 Batch 1:  Loss:     1.2620 Validation Accuracy: 0.585200
# Epoch  6, CIFAR-10 Batch 2:  Loss:     1.0302 Validation Accuracy: 0.616600
# Epoch  6, CIFAR-10 Batch 3:  Loss:     0.8466 Validation Accuracy: 0.602400
# Epoch  6, CIFAR-10 Batch 4:  Loss:     0.9903 Validation Accuracy: 0.610400
# Epoch  6, CIFAR-10 Batch 5:  Loss:     0.9256 Validation Accuracy: 0.622400
# Epoch  7, CIFAR-10 Batch 1:  Loss:     1.1109 Validation Accuracy: 0.607600
# Epoch  7, CIFAR-10 Batch 2:  Loss:     0.9794 Validation Accuracy: 0.621800
# Epoch  7, CIFAR-10 Batch 3:  Loss:     0.7348 Validation Accuracy: 0.602200
# Epoch  7, CIFAR-10 Batch 4:  Loss:     0.9249 Validation Accuracy: 0.616600
# Epoch  7, CIFAR-10 Batch 5:  Loss:     0.8979 Validation Accuracy: 0.620400
# Epoch  8, CIFAR-10 Batch 1:  Loss:     1.1002 Validation Accuracy: 0.618200
# Epoch  8, CIFAR-10 Batch 2:  Loss:     0.9039 Validation Accuracy: 0.614200
# Epoch  8, CIFAR-10 Batch 3:  Loss:     0.7208 Validation Accuracy: 0.620200
# Epoch  8, CIFAR-10 Batch 4:  Loss:     0.8524 Validation Accuracy: 0.630200
# Epoch  8, CIFAR-10 Batch 5:  Loss:     0.7783 Validation Accuracy: 0.635800
# Epoch  9, CIFAR-10 Batch 1:  Loss:     1.0343 Validation Accuracy: 0.625400
# Epoch  9, CIFAR-10 Batch 2:  Loss:     0.8984 Validation Accuracy: 0.624800
# Epoch  9, CIFAR-10 Batch 3:  Loss:     0.6334 Validation Accuracy: 0.634400
# Epoch  9, CIFAR-10 Batch 4:  Loss:     0.8425 Validation Accuracy: 0.632600
# Epoch  9, CIFAR-10 Batch 5:  Loss:     0.7977 Validation Accuracy: 0.627600
# Epoch 10, CIFAR-10 Batch 1:  Loss:     0.9038 Validation Accuracy: 0.623800
# Epoch 10, CIFAR-10 Batch 2:  Loss:     0.8279 Validation Accuracy: 0.630600
# Epoch 10, CIFAR-10 Batch 3:  Loss:     0.6171 Validation Accuracy: 0.635400
# Epoch 10, CIFAR-10 Batch 4:  Loss:     0.7422 Validation Accuracy: 0.633000
# Epoch 10, CIFAR-10 Batch 5:  Loss:     0.6699 Validation Accuracy: 0.651000
# Epoch 11, CIFAR-10 Batch 1:  Loss:     0.9086 Validation Accuracy: 0.621400
# Epoch 11, CIFAR-10 Batch 2:  Loss:     0.7930 Validation Accuracy: 0.640800
# Epoch 11, CIFAR-10 Batch 3:  Loss:     0.6182 Validation Accuracy: 0.646800
# Epoch 11, CIFAR-10 Batch 4:  Loss:     0.7070 Validation Accuracy: 0.640200
# Epoch 11, CIFAR-10 Batch 5:  Loss:     0.6159 Validation Accuracy: 0.646600
# Epoch 12, CIFAR-10 Batch 1:  Loss:     0.8496 Validation Accuracy: 0.629400
# Epoch 12, CIFAR-10 Batch 2:  Loss:     0.8260 Validation Accuracy: 0.633400
# Epoch 12, CIFAR-10 Batch 3:  Loss:     0.6499 Validation Accuracy: 0.628800
# Epoch 12, CIFAR-10 Batch 4:  Loss:     0.6864 Validation Accuracy: 0.651000
# Epoch 12, CIFAR-10 Batch 5:  Loss:     0.5862 Validation Accuracy: 0.649000
# Epoch 13, CIFAR-10 Batch 1:  Loss:     0.8905 Validation Accuracy: 0.631200
# Epoch 13, CIFAR-10 Batch 2:  Loss:     0.8263 Validation Accuracy: 0.639600
# Epoch 13, CIFAR-10 Batch 3:  Loss:     0.5690 Validation Accuracy: 0.645400
# Epoch 13, CIFAR-10 Batch 4:  Loss:     0.6404 Validation Accuracy: 0.642000
# Epoch 13, CIFAR-10 Batch 5:  Loss:     0.5541 Validation Accuracy: 0.654000
# Epoch 14, CIFAR-10 Batch 1:  Loss:     0.8253 Validation Accuracy: 0.638400
# Epoch 14, CIFAR-10 Batch 2:  Loss:     0.7800 Validation Accuracy: 0.642000
# Epoch 14, CIFAR-10 Batch 3:  Loss:     0.5849 Validation Accuracy: 0.637800
# Epoch 14, CIFAR-10 Batch 4:  Loss:     0.6001 Validation Accuracy: 0.646600
# Epoch 14, CIFAR-10 Batch 5:  Loss:     0.5391 Validation Accuracy: 0.637600
# Epoch 15, CIFAR-10 Batch 1:  Loss:     0.7775 Validation Accuracy: 0.647800
# Epoch 15, CIFAR-10 Batch 2:  Loss:     0.7580 Validation Accuracy: 0.635600
# Epoch 15, CIFAR-10 Batch 3:  Loss:     0.5840 Validation Accuracy: 0.645200
# Epoch 15, CIFAR-10 Batch 4:  Loss:     0.5636 Validation Accuracy: 0.654200
# Epoch 15, CIFAR-10 Batch 5:  Loss:     0.5376 Validation Accuracy: 0.644400
# Epoch 16, CIFAR-10 Batch 1:  Loss:     0.7676 Validation Accuracy: 0.651800
# Epoch 16, CIFAR-10 Batch 2:  Loss:     0.7375 Validation Accuracy: 0.631200
# Epoch 16, CIFAR-10 Batch 3:  Loss:     0.5456 Validation Accuracy: 0.636600
# Epoch 16, CIFAR-10 Batch 4:  Loss:     0.5866 Validation Accuracy: 0.654600
# Epoch 16, CIFAR-10 Batch 5:  Loss:     0.4445 Validation Accuracy: 0.657400
# Epoch 17, CIFAR-10 Batch 1:  Loss:     0.6730 Validation Accuracy: 0.655000
# Epoch 17, CIFAR-10 Batch 2:  Loss:     0.7370 Validation Accuracy: 0.649200
# Epoch 17, CIFAR-10 Batch 3:  Loss:     0.5176 Validation Accuracy: 0.632600
# Epoch 17, CIFAR-10 Batch 4:  Loss:     0.5208 Validation Accuracy: 0.663800
# Epoch 17, CIFAR-10 Batch 5:  Loss:     0.4571 Validation Accuracy: 0.633600
# Epoch 18, CIFAR-10 Batch 1:  Loss:     0.6025 Validation Accuracy: 0.665200
# Epoch 18, CIFAR-10 Batch 2:  Loss:     0.6388 Validation Accuracy: 0.643000
# Epoch 18, CIFAR-10 Batch 3:  Loss:     0.5259 Validation Accuracy: 0.642000
# Epoch 18, CIFAR-10 Batch 4:  Loss:     0.5032 Validation Accuracy: 0.656800
# Epoch 18, CIFAR-10 Batch 5:  Loss:     0.4078 Validation Accuracy: 0.635400
# Epoch 19, CIFAR-10 Batch 1:  Loss:     0.6504 Validation Accuracy: 0.656800
# Epoch 19, CIFAR-10 Batch 2:  Loss:     0.5601 Validation Accuracy: 0.658600
# Epoch 19, CIFAR-10 Batch 3:  Loss:     0.4821 Validation Accuracy: 0.634600
# Epoch 19, CIFAR-10 Batch 4:  Loss:     0.4949 Validation Accuracy: 0.661000
# Epoch 19, CIFAR-10 Batch 5:  Loss:     0.3704 Validation Accuracy: 0.650200
# Epoch 20, CIFAR-10 Batch 1:  Loss:     0.6181 Validation Accuracy: 0.655000
# Epoch 20, CIFAR-10 Batch 2:  Loss:     0.6058 Validation Accuracy: 0.646200
# Epoch 20, CIFAR-10 Batch 3:  Loss:     0.5002 Validation Accuracy: 0.636200
# Epoch 20, CIFAR-10 Batch 4:  Loss:     0.4780 Validation Accuracy: 0.662800
# Epoch 20, CIFAR-10 Batch 5:  Loss:     0.3543 Validation Accuracy: 0.646800
# Epoch 21, CIFAR-10 Batch 1:  Loss:     0.6227 Validation Accuracy: 0.653000
# Epoch 21, CIFAR-10 Batch 2:  Loss:     0.5472 Validation Accuracy: 0.647800
# Epoch 21, CIFAR-10 Batch 3:  Loss:     0.4403 Validation Accuracy: 0.644200
# Epoch 21, CIFAR-10 Batch 4:  Loss:     0.4750 Validation Accuracy: 0.658800
# Epoch 21, CIFAR-10 Batch 5:  Loss:     0.3096 Validation Accuracy: 0.653200
# Epoch 22, CIFAR-10 Batch 1:  Loss:     0.5413 Validation Accuracy: 0.666000
# Epoch 22, CIFAR-10 Batch 2:  Loss:     0.4910 Validation Accuracy: 0.652800
# Epoch 22, CIFAR-10 Batch 3:  Loss:     0.4481 Validation Accuracy: 0.647600
# Epoch 22, CIFAR-10 Batch 4:  Loss:     0.4600 Validation Accuracy: 0.665000
# Epoch 22, CIFAR-10 Batch 5:  Loss:     0.3333 Validation Accuracy: 0.658200
# Epoch 23, CIFAR-10 Batch 1:  Loss:     0.5097 Validation Accuracy: 0.664600
# Epoch 23, CIFAR-10 Batch 2:  Loss:     0.4320 Validation Accuracy: 0.653200
# Epoch 23, CIFAR-10 Batch 3:  Loss:     0.4171 Validation Accuracy: 0.655000
# Epoch 23, CIFAR-10 Batch 4:  Loss:     0.4121 Validation Accuracy: 0.667600
# Epoch 23, CIFAR-10 Batch 5:  Loss:     0.2736 Validation Accuracy: 0.649600
# Epoch 24, CIFAR-10 Batch 1:  Loss:     0.5054 Validation Accuracy: 0.657600
# Epoch 24, CIFAR-10 Batch 2:  Loss:     0.4431 Validation Accuracy: 0.657000
# Epoch 24, CIFAR-10 Batch 3:  Loss:     0.3643 Validation Accuracy: 0.653600
# Epoch 24, CIFAR-10 Batch 4:  Loss:     0.3622 Validation Accuracy: 0.666000
# Epoch 24, CIFAR-10 Batch 5:  Loss:     0.2802 Validation Accuracy: 0.653600
# Epoch 25, CIFAR-10 Batch 1:  Loss:     0.4420 Validation Accuracy: 0.655000
# Epoch 25, CIFAR-10 Batch 2:  Loss:     0.4091 Validation Accuracy: 0.653400
# Epoch 25, CIFAR-10 Batch 3:  Loss:     0.3632 Validation Accuracy: 0.639600
# Epoch 25, CIFAR-10 Batch 4:  Loss:     0.3846 Validation Accuracy: 0.659800
# Epoch 25, CIFAR-10 Batch 5:  Loss:     0.2766 Validation Accuracy: 0.646600
# Epoch 26, CIFAR-10 Batch 1:  Loss:     0.4305 Validation Accuracy: 0.661400
# Epoch 26, CIFAR-10 Batch 2:  Loss:     0.4050 Validation Accuracy: 0.657400
# Epoch 26, CIFAR-10 Batch 3:  Loss:     0.3504 Validation Accuracy: 0.658000
# Epoch 26, CIFAR-10 Batch 4:  Loss:     0.3191 Validation Accuracy: 0.665800
# Epoch 26, CIFAR-10 Batch 5:  Loss:     0.2289 Validation Accuracy: 0.663400
# Epoch 27, CIFAR-10 Batch 1:  Loss:     0.4009 Validation Accuracy: 0.661400
# Epoch 27, CIFAR-10 Batch 2:  Loss:     0.3645 Validation Accuracy: 0.656000
# Epoch 27, CIFAR-10 Batch 3:  Loss:     0.3882 Validation Accuracy: 0.651200
# Epoch 27, CIFAR-10 Batch 4:  Loss:     0.3728 Validation Accuracy: 0.655600
# Epoch 27, CIFAR-10 Batch 5:  Loss:     0.2559 Validation Accuracy: 0.664800
# Epoch 28, CIFAR-10 Batch 1:  Loss:     0.4403 Validation Accuracy: 0.658000
# Epoch 28, CIFAR-10 Batch 2:  Loss:     0.3362 Validation Accuracy: 0.654800
# Epoch 28, CIFAR-10 Batch 3:  Loss:     0.3157 Validation Accuracy: 0.648200
# Epoch 28, CIFAR-10 Batch 4:  Loss:     0.3176 Validation Accuracy: 0.666000
# Epoch 28, CIFAR-10 Batch 5:  Loss:     0.2341 Validation Accuracy: 0.655600
# Epoch 29, CIFAR-10 Batch 1:  Loss:     0.3795 Validation Accuracy: 0.654800
# Epoch 29, CIFAR-10 Batch 2:  Loss:     0.2862 Validation Accuracy: 0.654600
# Epoch 29, CIFAR-10 Batch 3:  Loss:     0.3107 Validation Accuracy: 0.655400
# Epoch 29, CIFAR-10 Batch 4:  Loss:     0.2971 Validation Accuracy: 0.658800
# Epoch 29, CIFAR-10 Batch 5:  Loss:     0.2401 Validation Accuracy: 0.645800
# Epoch 30, CIFAR-10 Batch 1:  Loss:     0.3775 Validation Accuracy: 0.656800
# Epoch 30, CIFAR-10 Batch 2:  Loss:     0.3478 Validation Accuracy: 0.649200
# Epoch 30, CIFAR-10 Batch 3:  Loss:     0.3027 Validation Accuracy: 0.654000
# Epoch 30, CIFAR-10 Batch 4:  Loss:     0.3276 Validation Accuracy: 0.654800
# Epoch 30, CIFAR-10 Batch 5:  Loss:     0.2080 Validation Accuracy: 0.648200
# Epoch 31, CIFAR-10 Batch 1:  Loss:     0.3367 Validation Accuracy: 0.666000
# Epoch 31, CIFAR-10 Batch 2:  Loss:     0.2993 Validation Accuracy: 0.643200
# Epoch 31, CIFAR-10 Batch 3:  Loss:     0.2914 Validation Accuracy: 0.653000
# Epoch 31, CIFAR-10 Batch 4:  Loss:     0.2987 Validation Accuracy: 0.659600
# Epoch 31, CIFAR-10 Batch 5:  Loss:     0.2097 Validation Accuracy: 0.650000
# Epoch 32, CIFAR-10 Batch 1:  Loss:     0.3704 Validation Accuracy: 0.650200
# Epoch 32, CIFAR-10 Batch 2:  Loss:     0.2899 Validation Accuracy: 0.648000
# Epoch 32, CIFAR-10 Batch 3:  Loss:     0.2435 Validation Accuracy: 0.654000
# Epoch 32, CIFAR-10 Batch 4:  Loss:     0.3369 Validation Accuracy: 0.662400
# Epoch 32, CIFAR-10 Batch 5:  Loss:     0.2138 Validation Accuracy: 0.645800
# Epoch 33, CIFAR-10 Batch 1:  Loss:     0.3356 Validation Accuracy: 0.653800
# Epoch 33, CIFAR-10 Batch 2:  Loss:     0.2731 Validation Accuracy: 0.641200
# Epoch 33, CIFAR-10 Batch 3:  Loss:     0.2832 Validation Accuracy: 0.652800
# Epoch 33, CIFAR-10 Batch 4:  Loss:     0.2933 Validation Accuracy: 0.658800
# Epoch 33, CIFAR-10 Batch 5:  Loss:     0.2457 Validation Accuracy: 0.635200
# Epoch 34, CIFAR-10 Batch 1:  Loss:     0.2942 Validation Accuracy: 0.650400
# Epoch 34, CIFAR-10 Batch 2:  Loss:     0.2666 Validation Accuracy: 0.636200
# Epoch 34, CIFAR-10 Batch 3:  Loss:     0.2136 Validation Accuracy: 0.660200
# Epoch 34, CIFAR-10 Batch 4:  Loss:     0.3063 Validation Accuracy: 0.650400
# Epoch 34, CIFAR-10 Batch 5:  Loss:     0.1953 Validation Accuracy: 0.654000
# Epoch 35, CIFAR-10 Batch 1:  Loss:     0.3146 Validation Accuracy: 0.666200
# Epoch 35, CIFAR-10 Batch 2:  Loss:     0.2649 Validation Accuracy: 0.646400
# Epoch 35, CIFAR-10 Batch 3:  Loss:     0.2150 Validation Accuracy: 0.666400
# Epoch 35, CIFAR-10 Batch 4:  Loss:     0.2810 Validation Accuracy: 0.651600
# Epoch 35, CIFAR-10 Batch 5:  Loss:     0.1643 Validation Accuracy: 0.653400
# Epoch 36, CIFAR-10 Batch 1:  Loss:     0.2811 Validation Accuracy: 0.665800
# Epoch 36, CIFAR-10 Batch 2:  Loss:     0.2117 Validation Accuracy: 0.663400
# Epoch 36, CIFAR-10 Batch 3:  Loss:     0.1975 Validation Accuracy: 0.648000
# Epoch 36, CIFAR-10 Batch 4:  Loss:     0.2599 Validation Accuracy: 0.647400
# Epoch 36, CIFAR-10 Batch 5:  Loss:     0.1727 Validation Accuracy: 0.655600
# Epoch 37, CIFAR-10 Batch 1:  Loss:     0.2792 Validation Accuracy: 0.661400
# Epoch 37, CIFAR-10 Batch 2:  Loss:     0.2063 Validation Accuracy: 0.660800
# Epoch 37, CIFAR-10 Batch 3:  Loss:     0.2264 Validation Accuracy: 0.641800
# Epoch 37, CIFAR-10 Batch 4:  Loss:     0.2395 Validation Accuracy: 0.657600
# Epoch 37, CIFAR-10 Batch 5:  Loss:     0.1494 Validation Accuracy: 0.659200
# Epoch 38, CIFAR-10 Batch 1:  Loss:     0.2888 Validation Accuracy: 0.652600
# Epoch 38, CIFAR-10 Batch 2:  Loss:     0.2137 Validation Accuracy: 0.654800
# Epoch 38, CIFAR-10 Batch 3:  Loss:     0.1769 Validation Accuracy: 0.662600
# Epoch 38, CIFAR-10 Batch 4:  Loss:     0.2196 Validation Accuracy: 0.660600
# Epoch 38, CIFAR-10 Batch 5:  Loss:     0.1500 Validation Accuracy: 0.662200
# Epoch 39, CIFAR-10 Batch 1:  Loss:     0.2557 Validation Accuracy: 0.655600
# Epoch 39, CIFAR-10 Batch 2:  Loss:     0.1739 Validation Accuracy: 0.654800
# Epoch 39, CIFAR-10 Batch 3:  Loss:     0.2389 Validation Accuracy: 0.640400
# Epoch 39, CIFAR-10 Batch 4:  Loss:     0.2602 Validation Accuracy: 0.655400
# Epoch 39, CIFAR-10 Batch 5:  Loss:     0.1171 Validation Accuracy: 0.664400
# Epoch 40, CIFAR-10 Batch 1:  Loss:     0.1928 Validation Accuracy: 0.667000
# Epoch 40, CIFAR-10 Batch 2:  Loss:     0.1729 Validation Accuracy: 0.644000
# Epoch 40, CIFAR-10 Batch 3:  Loss:     0.1868 Validation Accuracy: 0.651000
# Epoch 40, CIFAR-10 Batch 4:  Loss:     0.2114 Validation Accuracy: 0.662000
# Epoch 40, CIFAR-10 Batch 5:  Loss:     0.1238 Validation Accuracy: 0.652400
# Epoch 41, CIFAR-10 Batch 1:  Loss:     0.2096 Validation Accuracy: 0.661200
# Epoch 41, CIFAR-10 Batch 2:  Loss:     0.1676 Validation Accuracy: 0.663200
# Epoch 41, CIFAR-10 Batch 3:  Loss:     0.1904 Validation Accuracy: 0.638000
# Epoch 41, CIFAR-10 Batch 4:  Loss:     0.1931 Validation Accuracy: 0.650000
# Epoch 41, CIFAR-10 Batch 5:  Loss:     0.1411 Validation Accuracy: 0.656600
# Epoch 42, CIFAR-10 Batch 1:  Loss:     0.2484 Validation Accuracy: 0.665200
# Epoch 42, CIFAR-10 Batch 2:  Loss:     0.1563 Validation Accuracy: 0.648800
# Epoch 42, CIFAR-10 Batch 3:  Loss:     0.1852 Validation Accuracy: 0.646600
# Epoch 42, CIFAR-10 Batch 4:  Loss:     0.2507 Validation Accuracy: 0.651400
# Epoch 42, CIFAR-10 Batch 5:  Loss:     0.1496 Validation Accuracy: 0.663600
# Epoch 43, CIFAR-10 Batch 1:  Loss:     0.2112 Validation Accuracy: 0.662800
# Epoch 43, CIFAR-10 Batch 2:  Loss:     0.1904 Validation Accuracy: 0.650000
# Epoch 43, CIFAR-10 Batch 3:  Loss:     0.1716 Validation Accuracy: 0.654000
# Epoch 43, CIFAR-10 Batch 4:  Loss:     0.2068 Validation Accuracy: 0.656600
# Epoch 43, CIFAR-10 Batch 5:  Loss:     0.1757 Validation Accuracy: 0.650400
# Epoch 44, CIFAR-10 Batch 1:  Loss:     0.2138 Validation Accuracy: 0.667000
# Epoch 44, CIFAR-10 Batch 2:  Loss:     0.1541 Validation Accuracy: 0.654400
# Epoch 44, CIFAR-10 Batch 3:  Loss:     0.1515 Validation Accuracy: 0.649200
# Epoch 44, CIFAR-10 Batch 4:  Loss:     0.1538 Validation Accuracy: 0.663400
# Epoch 44, CIFAR-10 Batch 5:  Loss:     0.1408 Validation Accuracy: 0.661800
# Epoch 45, CIFAR-10 Batch 1:  Loss:     0.2131 Validation Accuracy: 0.662800
# Epoch 45, CIFAR-10 Batch 2:  Loss:     0.1810 Validation Accuracy: 0.654800
# Epoch 45, CIFAR-10 Batch 3:  Loss:     0.1416 Validation Accuracy: 0.645200
# Epoch 45, CIFAR-10 Batch 4:  Loss:     0.1832 Validation Accuracy: 0.648800
# Epoch 45, CIFAR-10 Batch 5:  Loss:     0.1250 Validation Accuracy: 0.658600
# Epoch 46, CIFAR-10 Batch 1:  Loss:     0.2045 Validation Accuracy: 0.664200
# Epoch 46, CIFAR-10 Batch 2:  Loss:     0.1502 Validation Accuracy: 0.641000
# Epoch 46, CIFAR-10 Batch 3:  Loss:     0.1125 Validation Accuracy: 0.633800
# Epoch 46, CIFAR-10 Batch 4:  Loss:     0.1847 Validation Accuracy: 0.656800
# Epoch 46, CIFAR-10 Batch 5:  Loss:     0.1228 Validation Accuracy: 0.648800
# Epoch 47, CIFAR-10 Batch 1:  Loss:     0.2090 Validation Accuracy: 0.659400
# Epoch 47, CIFAR-10 Batch 2:  Loss:     0.1930 Validation Accuracy: 0.657200
# Epoch 47, CIFAR-10 Batch 3:  Loss:     0.1309 Validation Accuracy: 0.643200
# Epoch 47, CIFAR-10 Batch 4:  Loss:     0.1735 Validation Accuracy: 0.653800
# Epoch 47, CIFAR-10 Batch 5:  Loss:     0.1364 Validation Accuracy: 0.645000
# Epoch 48, CIFAR-10 Batch 1:  Loss:     0.1891 Validation Accuracy: 0.662200
# Epoch 48, CIFAR-10 Batch 2:  Loss:     0.1476 Validation Accuracy: 0.650600
# Epoch 48, CIFAR-10 Batch 3:  Loss:     0.1261 Validation Accuracy: 0.652800
# Epoch 48, CIFAR-10 Batch 4:  Loss:     0.1492 Validation Accuracy: 0.664800
# Epoch 48, CIFAR-10 Batch 5:  Loss:     0.1123 Validation Accuracy: 0.663000
# Epoch 49, CIFAR-10 Batch 1:  Loss:     0.2004 Validation Accuracy: 0.649800
# Epoch 49, CIFAR-10 Batch 2:  Loss:     0.1307 Validation Accuracy: 0.662600
# Epoch 49, CIFAR-10 Batch 3:  Loss:     0.1315 Validation Accuracy: 0.661200
# Epoch 49, CIFAR-10 Batch 4:  Loss:     0.1445 Validation Accuracy: 0.662600
# Epoch 49, CIFAR-10 Batch 5:  Loss:     0.1066 Validation Accuracy: 0.657000
# Epoch 50, CIFAR-10 Batch 1:  Loss:     0.1405 Validation Accuracy: 0.654800
# Epoch 50, CIFAR-10 Batch 2:  Loss:     0.1371 Validation Accuracy: 0.642400
# Epoch 50, CIFAR-10 Batch 3:  Loss:     0.1417 Validation Accuracy: 0.664000
# Epoch 50, CIFAR-10 Batch 4:  Loss:     0.2233 Validation Accuracy: 0.646200
# Epoch 50, CIFAR-10 Batch 5:  Loss:     0.1431 Validation Accuracy: 0.646800
# Epoch 51, CIFAR-10 Batch 1:  Loss:     0.2104 Validation Accuracy: 0.664000
# Epoch 51, CIFAR-10 Batch 2:  Loss:     0.1413 Validation Accuracy: 0.655800
# Epoch 51, CIFAR-10 Batch 3:  Loss:     0.1268 Validation Accuracy: 0.651000
# Epoch 51, CIFAR-10 Batch 4:  Loss:     0.1172 Validation Accuracy: 0.650400
# Epoch 51, CIFAR-10 Batch 5:  Loss:     0.1121 Validation Accuracy: 0.663400
# Epoch 52, CIFAR-10 Batch 1:  Loss:     0.1505 Validation Accuracy: 0.653400
# Epoch 52, CIFAR-10 Batch 2:  Loss:     0.1348 Validation Accuracy: 0.655600
# Epoch 52, CIFAR-10 Batch 3:  Loss:     0.1221 Validation Accuracy: 0.664800
# Epoch 52, CIFAR-10 Batch 4:  Loss:     0.1442 Validation Accuracy: 0.654400
# Epoch 52, CIFAR-10 Batch 5:  Loss:     0.1259 Validation Accuracy: 0.654200
# Epoch 53, CIFAR-10 Batch 1:  Loss:     0.1957 Validation Accuracy: 0.649600
# Epoch 53, CIFAR-10 Batch 2:  Loss:     0.1187 Validation Accuracy: 0.659200
# Epoch 53, CIFAR-10 Batch 3:  Loss:     0.1165 Validation Accuracy: 0.654800
# Epoch 53, CIFAR-10 Batch 4:  Loss:     0.1071 Validation Accuracy: 0.652800
# Epoch 53, CIFAR-10 Batch 5:  Loss:     0.1269 Validation Accuracy: 0.660200
# Epoch 54, CIFAR-10 Batch 1:  Loss:     0.1753 Validation Accuracy: 0.657000
# Epoch 54, CIFAR-10 Batch 2:  Loss:     0.1172 Validation Accuracy: 0.655800
# Epoch 54, CIFAR-10 Batch 3:  Loss:     0.1068 Validation Accuracy: 0.647800
# Epoch 54, CIFAR-10 Batch 4:  Loss:     0.1076 Validation Accuracy: 0.646200
# Epoch 54, CIFAR-10 Batch 5:  Loss:     0.0854 Validation Accuracy: 0.659800
# Epoch 55, CIFAR-10 Batch 1:  Loss:     0.1368 Validation Accuracy: 0.655600
# Epoch 55, CIFAR-10 Batch 2:  Loss:     0.1555 Validation Accuracy: 0.660200
# Epoch 55, CIFAR-10 Batch 3:  Loss:     0.0836 Validation Accuracy: 0.653600
# Epoch 55, CIFAR-10 Batch 4:  Loss:     0.1146 Validation Accuracy: 0.653800
# Epoch 55, CIFAR-10 Batch 5:  Loss:     0.0840 Validation Accuracy: 0.654600
# Epoch 56, CIFAR-10 Batch 1:  Loss:     0.1792 Validation Accuracy: 0.654000
# Epoch 56, CIFAR-10 Batch 2:  Loss:     0.1838 Validation Accuracy: 0.656400
# Epoch 56, CIFAR-10 Batch 3:  Loss:     0.1060 Validation Accuracy: 0.656000
# Epoch 56, CIFAR-10 Batch 4:  Loss:     0.1030 Validation Accuracy: 0.659400
# Epoch 56, CIFAR-10 Batch 5:  Loss:     0.0698 Validation Accuracy: 0.658600
# Epoch 57, CIFAR-10 Batch 1:  Loss:     0.1436 Validation Accuracy: 0.647800
# Epoch 57, CIFAR-10 Batch 2:  Loss:     0.1150 Validation Accuracy: 0.653000
# Epoch 57, CIFAR-10 Batch 3:  Loss:     0.1105 Validation Accuracy: 0.642000
# Epoch 57, CIFAR-10 Batch 4:  Loss:     0.1307 Validation Accuracy: 0.651800
# Epoch 57, CIFAR-10 Batch 5:  Loss:     0.0838 Validation Accuracy: 0.655400
# Epoch 58, CIFAR-10 Batch 1:  Loss:     0.1201 Validation Accuracy: 0.659200
# Epoch 58, CIFAR-10 Batch 2:  Loss:     0.1574 Validation Accuracy: 0.658400
# Epoch 58, CIFAR-10 Batch 3:  Loss:     0.0906 Validation Accuracy: 0.649400
# Epoch 58, CIFAR-10 Batch 4:  Loss:     0.1031 Validation Accuracy: 0.662000
# Epoch 58, CIFAR-10 Batch 5:  Loss:     0.0849 Validation Accuracy: 0.648400
# Epoch 59, CIFAR-10 Batch 1:  Loss:     0.1287 Validation Accuracy: 0.661400
# Epoch 59, CIFAR-10 Batch 2:  Loss:     0.0971 Validation Accuracy: 0.654200
# Epoch 59, CIFAR-10 Batch 3:  Loss:     0.0952 Validation Accuracy: 0.649200
# Epoch 59, CIFAR-10 Batch 4:  Loss:     0.0914 Validation Accuracy: 0.659800
# Epoch 59, CIFAR-10 Batch 5:  Loss:     0.0803 Validation Accuracy: 0.657400
# Epoch 60, CIFAR-10 Batch 1:  Loss:     0.1022 Validation Accuracy: 0.659200
# Epoch 60, CIFAR-10 Batch 2:  Loss:     0.1073 Validation Accuracy: 0.660000
# Epoch 60, CIFAR-10 Batch 3:  Loss:     0.0826 Validation Accuracy: 0.655200
# Epoch 60, CIFAR-10 Batch 4:  Loss:     0.1062 Validation Accuracy: 0.655000
# Epoch 60, CIFAR-10 Batch 5:  Loss:     0.0757 Validation Accuracy: 0.651400
# Epoch 61, CIFAR-10 Batch 1:  Loss:     0.1282 Validation Accuracy: 0.666600
# Epoch 61, CIFAR-10 Batch 2:  Loss:     0.1250 Validation Accuracy: 0.655800
# Epoch 61, CIFAR-10 Batch 3:  Loss:     0.0644 Validation Accuracy: 0.656600
# Epoch 61, CIFAR-10 Batch 4:  Loss:     0.0823 Validation Accuracy: 0.663600
# Epoch 61, CIFAR-10 Batch 5:  Loss:     0.0922 Validation Accuracy: 0.651000
# Epoch 62, CIFAR-10 Batch 1:  Loss:     0.1078 Validation Accuracy: 0.669400
# Epoch 62, CIFAR-10 Batch 2:  Loss:     0.1015 Validation Accuracy: 0.665000
# Epoch 62, CIFAR-10 Batch 3:  Loss:     0.0960 Validation Accuracy: 0.655000
# Epoch 62, CIFAR-10 Batch 4:  Loss:     0.0833 Validation Accuracy: 0.657600
# Epoch 62, CIFAR-10 Batch 5:  Loss:     0.0830 Validation Accuracy: 0.653200
# Epoch 63, CIFAR-10 Batch 1:  Loss:     0.1252 Validation Accuracy: 0.659800
# Epoch 63, CIFAR-10 Batch 2:  Loss:     0.0929 Validation Accuracy: 0.661400
# Epoch 63, CIFAR-10 Batch 3:  Loss:     0.0720 Validation Accuracy: 0.658800
# Epoch 63, CIFAR-10 Batch 4:  Loss:     0.0896 Validation Accuracy: 0.657800
# Epoch 63, CIFAR-10 Batch 5:  Loss:     0.0745 Validation Accuracy: 0.650800
# Epoch 64, CIFAR-10 Batch 1:  Loss:     0.1546 Validation Accuracy: 0.657800
# Epoch 64, CIFAR-10 Batch 2:  Loss:     0.1020 Validation Accuracy: 0.663400
# Epoch 64, CIFAR-10 Batch 3:  Loss:     0.0926 Validation Accuracy: 0.653200
# Epoch 64, CIFAR-10 Batch 4:  Loss:     0.0913 Validation Accuracy: 0.655000
# Epoch 64, CIFAR-10 Batch 5:  Loss:     0.1076 Validation Accuracy: 0.647400
# Epoch 65, CIFAR-10 Batch 1:  Loss:     0.1139 Validation Accuracy: 0.660000
# Epoch 65, CIFAR-10 Batch 2:  Loss:     0.1189 Validation Accuracy: 0.649800
# Epoch 65, CIFAR-10 Batch 3:  Loss:     0.0744 Validation Accuracy: 0.653000
# Epoch 65, CIFAR-10 Batch 4:  Loss:     0.1100 Validation Accuracy: 0.661400
# Epoch 65, CIFAR-10 Batch 5:  Loss:     0.0914 Validation Accuracy: 0.651200
# Epoch 66, CIFAR-10 Batch 1:  Loss:     0.0854 Validation Accuracy: 0.668400
# Epoch 66, CIFAR-10 Batch 2:  Loss:     0.0923 Validation Accuracy: 0.660800
# Epoch 66, CIFAR-10 Batch 3:  Loss:     0.0642 Validation Accuracy: 0.646400
# Epoch 66, CIFAR-10 Batch 4:  Loss:     0.0877 Validation Accuracy: 0.662200
# Epoch 66, CIFAR-10 Batch 5:  Loss:     0.0726 Validation Accuracy: 0.654000
# Epoch 67, CIFAR-10 Batch 1:  Loss:     0.1076 Validation Accuracy: 0.658600
# Epoch 67, CIFAR-10 Batch 2:  Loss:     0.0905 Validation Accuracy: 0.658800
# Epoch 67, CIFAR-10 Batch 3:  Loss:     0.0705 Validation Accuracy: 0.652200
# Epoch 67, CIFAR-10 Batch 4:  Loss:     0.0776 Validation Accuracy: 0.663800
# Epoch 67, CIFAR-10 Batch 5:  Loss:     0.1085 Validation Accuracy: 0.635400
# Epoch 68, CIFAR-10 Batch 1:  Loss:     0.0906 Validation Accuracy: 0.668200
# Epoch 68, CIFAR-10 Batch 2:  Loss:     0.1235 Validation Accuracy: 0.651600
# Epoch 68, CIFAR-10 Batch 3:  Loss:     0.0586 Validation Accuracy: 0.649400
# Epoch 68, CIFAR-10 Batch 4:  Loss:     0.0764 Validation Accuracy: 0.664600
# Epoch 68, CIFAR-10 Batch 5:  Loss:     0.0775 Validation Accuracy: 0.654200
# Epoch 69, CIFAR-10 Batch 1:  Loss:     0.1064 Validation Accuracy: 0.663000
# Epoch 69, CIFAR-10 Batch 2:  Loss:     0.1098 Validation Accuracy: 0.661800
# Epoch 69, CIFAR-10 Batch 3:  Loss:     0.0677 Validation Accuracy: 0.651800
# Epoch 69, CIFAR-10 Batch 4:  Loss:     0.0913 Validation Accuracy: 0.663200
# Epoch 69, CIFAR-10 Batch 5:  Loss:     0.0723 Validation Accuracy: 0.652000
# Epoch 70, CIFAR-10 Batch 1:  Loss:     0.1111 Validation Accuracy: 0.656000
# Epoch 70, CIFAR-10 Batch 2:  Loss:     0.1014 Validation Accuracy: 0.661000
# Epoch 70, CIFAR-10 Batch 3:  Loss:     0.0411 Validation Accuracy: 0.655000
# Epoch 70, CIFAR-10 Batch 4:  Loss:     0.0876 Validation Accuracy: 0.660400
# Epoch 70, CIFAR-10 Batch 5:  Loss:     0.0562 Validation Accuracy: 0.644800
# Epoch 71, CIFAR-10 Batch 1:  Loss:     0.1135 Validation Accuracy: 0.655600
# Epoch 71, CIFAR-10 Batch 2:  Loss:     0.0991 Validation Accuracy: 0.663800
# Epoch 71, CIFAR-10 Batch 3:  Loss:     0.0508 Validation Accuracy: 0.653800
# Epoch 71, CIFAR-10 Batch 4:  Loss:     0.0639 Validation Accuracy: 0.666800
# Epoch 71, CIFAR-10 Batch 5:  Loss:     0.0722 Validation Accuracy: 0.648600
# Epoch 72, CIFAR-10 Batch 1:  Loss:     0.0833 Validation Accuracy: 0.658600
# Epoch 72, CIFAR-10 Batch 2:  Loss:     0.1081 Validation Accuracy: 0.656200
# Epoch 72, CIFAR-10 Batch 3:  Loss:     0.0511 Validation Accuracy: 0.649600
# Epoch 72, CIFAR-10 Batch 4:  Loss:     0.0684 Validation Accuracy: 0.665200
# Epoch 72, CIFAR-10 Batch 5:  Loss:     0.0579 Validation Accuracy: 0.664000
# Epoch 73, CIFAR-10 Batch 1:  Loss:     0.0982 Validation Accuracy: 0.663400
# Epoch 73, CIFAR-10 Batch 2:  Loss:     0.1026 Validation Accuracy: 0.662800
# Epoch 73, CIFAR-10 Batch 3:  Loss:     0.0606 Validation Accuracy: 0.649400
# Epoch 73, CIFAR-10 Batch 4:  Loss:     0.0946 Validation Accuracy: 0.660000
# Epoch 73, CIFAR-10 Batch 5:  Loss:     0.0526 Validation Accuracy: 0.654000
# Epoch 74, CIFAR-10 Batch 1:  Loss:     0.0825 Validation Accuracy: 0.654000
# Epoch 74, CIFAR-10 Batch 2:  Loss:     0.0988 Validation Accuracy: 0.656000
# Epoch 74, CIFAR-10 Batch 3:  Loss:     0.0600 Validation Accuracy: 0.646800
# Epoch 74, CIFAR-10 Batch 4:  Loss:     0.0864 Validation Accuracy: 0.666600
# Epoch 74, CIFAR-10 Batch 5:  Loss:     0.0612 Validation Accuracy: 0.653400
# Epoch 75, CIFAR-10 Batch 1:  Loss:     0.1051 Validation Accuracy: 0.665400
# Epoch 75, CIFAR-10 Batch 2:  Loss:     0.0834 Validation Accuracy: 0.652600
# Epoch 75, CIFAR-10 Batch 3:  Loss:     0.0662 Validation Accuracy: 0.647000
# Epoch 75, CIFAR-10 Batch 4:  Loss:     0.0599 Validation Accuracy: 0.663000
# Epoch 75, CIFAR-10 Batch 5:  Loss:     0.0520 Validation Accuracy: 0.654200

# %% [markdown]
# # Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_training.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for train_feature_batch, train_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: train_feature_batch, loaded_y: train_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# Testing Accuracy: 0.6548726246991289

# %% [markdown]
# ## Why 50-80% Accuracy?
# You might be wondering why you can't get an accuracy any higher. First things first, 50% isn't bad for a simple CNN.  Pure guessing would get you 10% accuracy. However, you might notice people are getting scores [well above 80%](http://rodrigob.github.io/are_we_there_yet/build/classification_datasets_results.html#43494641522d3130).  That's because we haven't taught you all there is to know about neural networks. We still need to cover a few more techniques.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook.  Save the notebook file as "dlnd_image_classification.ipynb" and save it as a HTML file under "File" -> "Download as".  Include the "helper.py" and "problem_unittests.py" files in your submission.
